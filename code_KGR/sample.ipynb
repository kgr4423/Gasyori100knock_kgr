# %% [markdown]
# #初期設定

# %%
# !echo "Google Driveをマウントします"
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Google Driveをマウントします
# Mounted at /content/drive

# %%
# !echo "今回の作業用フォルダに移動します"
# %cd /content/drive/My\ Drive/Gasyori100knock_kgr
# !ls
# Out:
# 今回の作業用フォルダに移動します
# /content/drive/My Drive/Gasyori100knock_kgr
# assets			     Question_11_20  Question_71_80    sample.py
# Dataset			     Question_21_30  Question_81_90    Tutorial
# Image_processing_tips.ipynb  Question_31_40  Question_91_100   yobi
# LICENSE			     Question_41_50  README.md
# memo.md			     Question_51_60  requirements.txt
# Question_01_10		     Question_61_70  sample.ipynb

# %% [markdown]
# #ライブラリ インポート

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #画像読み込み、表示

# %%
img = cv2.imread("assets/imori.jpg")
img.shape
# Out:
# (128, 128, 3)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
plt.axis('off')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread("assets/imori.jpeg")
